# %% [markdown]
# # Figure 4d. Microglia-specific eQTL colocalization in FCGR2A.
#
# The CoS-gene link from microglia-specific eQTL colocalization in FCGR2A is validated by CRISPRi in K562 cells.

# %%
for(file in list.files("/Users/xueweic/Documents/GitHub/statfungen/colocboost/R", full.names = T)) {source(file)}

# %%
res <- readRDS("Figure_4d_FCGR2A.rds")

# %%
options(repr.plot.width = 8, repr.plot.height = 8)
colocboost_plot(res, variant_coord = TRUE, plot_cols = 1)
# Out:
# plot without title

# %%
res$cos_details$cos_outcomes_npc
# Out:
# $`cos1:y1_y2_y3_y4`
#       outcomes_index relative_logLR npc_outcome strong_effect
# AC                 3      2.2861263   0.9896653          TRUE
# DLPFC              2      1.6324724   0.9618010          TRUE
# PCC                4      1.1526294   0.9002670          TRUE
# Mic                1      0.3500961   0.5035101         FALSE

# %%
colocboost_plot(res, variant_coord = TRUE, pos = c(25100:26300), plot_cols = 1)
# Out:
# plot without title
